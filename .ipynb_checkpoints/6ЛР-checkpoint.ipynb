# %%
import pandas as pd
import matplotlib as mpl
from pylab import *
import seaborn as sns

# %%
# 0) Описание датафрейма

# %% [markdown]
# <h2>DataFrame employees.csv</h2>
# <p>DataFrame содержит информацию о сотрудниках:</p>
# <h3>Описание столбцов:</h3>
# <p>First Name:</p>
# <p>Имя сотрудника, тип данных текстовый</p>
# <p>Gender:</p>
# <p>Пол, тип данных категориальный</p>
# <p>Male - мужчина</p>
# <p>Female - женщина</p>
# <p>NaN - неуказан</p>
# <p>Start Date:</p>
# <p>Дата зачисление на работу, тип данных текстовый</p>
# <p>Last Login Time:</p>
# <p>Время последнего выхода в сеть, тип данных текстовый</p>
# <p>Salary:</p>
# <p>Заработная плата, тип данных целочисленный</p>
# <p>Bonus %</p>
# <p>Бонус к зарплате,тип данных вещественный</p>
# <p>Senior Management:</p>
# <p>Статус руководителя, тип данных категориальный</p>
# <p>True - да</p>
# <p>Flase - нет</p>
# <p>Team:</p>
# <p>Подразделение, тип данных текстовый</p>

# %%
df = pd.read_csv('employees.csv')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945  \
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
# 1.1) Построить любой график (любого рода) с помощью чистого matplotlib / pylab
# 1.2) Построить несколько суб-графиков на одном графике используя .subplot.
# Графики должны быть разных типов и хотя бы два из них должны быть связаны с вашим датасетом. 
# Хотя бы в одном графике подпишите оси. Во всех графиках подписать название графика.
df = pd.read_csv('employees.csv')
salary_list = list(df['Salary'])
bonus_list = list(df['Bonus %'])
gender_list = list(df['Gender'])
plt.suptitle("DataFrame employees.csv")

plt.subplot(2, 2, 1)
plt.title("Salary")
plt.plot(salary_list[:30])

plt.subplot(2, 2, 2)
plt.title("Bonus%")
plt.plot(bonus_list[:30],color='r')

plt.subplot(2, 2, 3)
plt.title("Gender")
plt.xlabel("gender")
plt.ylabel("count")
plt.hist(gender_list,color='g')

plt.show()

# %%
# 2) На основе Вашего датасета построить три разных вида графиков используя 
# pandas.DataFrame.plot / Series.plot (мануал) 
# Среди графиков должен присутствовать один boxplot 
# (обязательно надо использовать параметр by, для исследования взаимосвязи числовой переменной и какой-либо другой). 
# Графики должны быть построены как через методы DataFrame, так и через методы Series. 
# То есть оба варианта нужно продемонстрировать.

# pandas.DataFrame.plot
df = pd.read_csv('employees.csv')
plt.subplot(2, 2, 1)
df["Salary"][:30].plot(color='r')


# Series.plot
plt.subplot(2, 2, 2)
bonus_list = list(df['Bonus %'])
a = pd.Series(bonus_list)[:30]
a.plot(color='g')

# boxplot
df.boxplot(by ='Team', column=['Salary'], grid= False , color='black')

plt.show()

# %%
# 3) Seaborn
# 3.1) Построить .pairplot с помощью seaborn на каком-либо наборе данных, 
# проанализировав взаимосвязь набора числовых переменных
df = pd.read_csv('employees.csv')
df[['Gender', 'First Name', 'Senior Management', 'Team', 'Last Login Time']] = df[['Gender', 'First Name', 'Senior Management', 'Team', 'Last Login Time']].astype(str)
df["Start Date"] = df["Start Date"].apply(pd.to_datetime)
sns.set(style="ticks", color_codes=True)
sns.pairplot(df)
plt.show()

# %%
# 3.2) Построить .jointplot
df = pd.read_csv('employees.csv')
sns.jointplot(df['Salary'])
plt.show()

# %%
# 3.3) Построить .boxplot или .violinplot на каком-либо наборе данных, 
# проанализировав какой-то числовой показатель в разрезе категориального
df = pd.read_csv('employees.csv')
Salary = df.Salary
Gender = df.Gender
sns.violinplot(x=Gender, y=Salary, data=df)
plt.show()

# %%
# 3.4) Построить график heatmap попарной корреляции всех числовых признаков 
# (категориальные признаки убираете из графика)
df = pd.read_csv('employees.csv')
df.drop (columns=df.columns[[0,1,2,3,6,7]], axis= 1 , inplace= True )
sns.heatmap(df)
plt.show()

# %%
# 4) Построить любой график (связанный с вашими данными) с помощью plotly
import plotly.graph_objects as go
df = pd.read_csv('employees.csv')
gender_list = list(df['Salary'])
fig = go.Figure(
    data=[go.Bar(y=gender_list[:20])],
    layout_title_text="Gender_Salary"
)
fig.show()
# Out:
# <div>                            <div id="1bfd8432-ca06-4191-8a96-42de79125760" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bfd8432-ca06-4191-8a96-42de79125760")) {                    Plotly.newPlot(                        "1bfd8432-ca06-4191-8a96-42de79125760",                        [{"y":[97308,61933,130590,138705,101004,115163,65476,45906,95570,139852,63241,102508,112807,109831,41426,59414,90370,111737,132940,81014],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar ...
#
# var gd = document.getElementById('1bfd8432-ca06-4191-8a96-42de79125760');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display ===
